# %% [markdown]
# #name: seba saud

# %% [markdown]
# # Student Performance Analysis
#
# ## Objective
# The goal of this notebook is to perform Exploratory Data Analysis (EDA)
# to understand the factors affecting student exam performance.
#
# We will explore:
# - Attendance effect on exam score
# - Study hours impact
# - Relationships between variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-darkgrid')
np.random.seed(42)

# %% [markdown]
# ## Type of Analysis
# This project focuses on Exploratory Data Analysis (EDA) to understand the factors affecting student performance.

# %% [markdown]
# ##  Load Dataset
# We load the dataset and check its structure.

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Data Understanding
#
# In this section, we explore the dataset structure, data types, and basic statistics to understand the data before analysis.

# %%
df.shape
df.dtypes
df.info()
df.head()
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6529 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %% [markdown]
# ## Data Overview
#
# We loaded the dataset and checked its structure, including:
# - Number of rows and columns
# - Column names
# - Data types
# - First few rows
#
# This helps ensure the data is correct before analysis.

# %% [markdown]
# توزيع الدرجات
# # Exam scores

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Exam_Score"], bins=20)
plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Insight
#
#
# Most students scored between 60 and 75, with the peak around 65–70.
#
# There are very few students with extremely high or very low scores, which indicates that the data is fairly balanced without extreme outliers.
#
# This suggests that the majority of students perform within an average range.

# %% [markdown]
# تحليل العلاقه
# # hours stdied vs exam score

# %%
sns.regplot(x="Hours_Studied", y="Exam_Score", line_kws={"color": "red"}, data=df )
plt.title("Hours Studied vs Exam Score")
plt.show()

# %% [markdown]
# ### Observation
#
# There is a positive relationship between study hours and exam score.
#
# Students who study more tend to get higher scores.

# %% [markdown]
# # sleeping hours vs exam score

# %%
df['Attendance_Status'] = pd.cut(df['Attendance'], bins=3, labels=['Low', 'Medium', 'High'])
plt.figure
sns.barplot(x='Attendance_Status', y='Exam_Score', data=df, hue='Attendance_Status', palette='Greens',  legend=True)
plt.title("Attendance vs Exam Success")
plt.xlabel("Attendance Level")
plt.ylabel("Average Exam Score")
plt.show()

# %% [markdown]
# ### Observation
#
# The relationship between sleep hours and exam score appears to be weak.
#
# Students with both low and high sleep hours show similar score distributions.
#
# This suggests that sleep alone is not a strong predictor of exam scores, and other factors may have a greater influence.

# %% [markdown]
# # استخدام  colleration  للتاكيد بالارقام
# قياس عامل الارتباط

# %%
df[["Hours_Studied","Sleep_Hours","Exam_Score"]].corr()
# Out:
#                Hours_Studied  Sleep_Hours  Exam_Score
# Hours_Studied       1.000000     0.010977    0.445455
# Sleep_Hours         0.010977     1.000000   -0.017022
# Exam_Score          0.445455    -0.017022    1.000000

# %% [markdown]
# ### Statistical Insight
#
# - The correlation between Hours_Studied and Exam_Score is (0.445).
# - This confirms a positive relationship.
#
#
# - The correlation between sleep_hours and Exam_Score is (-0.01).
#  - This confirms a negative relationship
#
# - The correlation between sleep_hours and Hours_Studied is (0.01).
# - This confirms no real relationship close to negative relationship

# %% [markdown]
# ## Attendance vs Exam Score
#
# We analyze whether attendance affects exam performance.

# %%
df["Attendance_Group"] = pd.cut(df["Attendance"], bins=5)
df.groupby("Attendance_Group")["Exam_Score"].mean().plot(kind="bar")
plt.title("Average Exam Score by Attendance Group")
plt.xlabel("Attendance Groups")
plt.ylabel("Average Exam Score")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Observation
#
# The bar chart shows a clear positive relationship between attendance and exam score.
#
# As attendance increases, the average exam score also increases.
#
# Students in higher attendance groups tend to achieve better results compared to those with lower attendance.
#
# This indicates that attendance is an important factor influencing student performance.

# %% [markdown]
# # متوسط الدرجات (Low,Meduim, High)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.boxplot(x="Motivation_Level", y="Exam_Score", data=df, palette="Set2", hue="Motivation_Level", legend=False)
plt.title("Exam Score Distribution by Motivation")
plt.show()

# %% [markdown]
# ### Observation
#
# There is a slight increase in exam scores as motivation level increases.
#
# However, the difference between groups is small, suggesting that motivation has a limited impact compared to other factors.

# %% [markdown]
# ## Correlation Heatmap
#
# We analyze the relationships between all numerical variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Observation
#
# - Hours_Studied shows a positive correlation with Exam_Score.
# - Attendance also has a positive relationship with Exam_Score.
# - Some variables have weak or no correlation.

# %% [markdown]
# ## Key Insights

# %% [markdown]
# 1. Students who study more hours tend to achieve higher exam scores.
# 2. Attendance has a positive impact on student performance.
# 3. Moderate sleep leads to better exam results.
# 4. Too little or too much sleep may reduce performance.
# 5. There is a clear positive relationship between study hours and exam scores.
# 6. Attendance and study hours together strongly affect performance.
# 7. Some factors have weak influence on exam scores.

# %% [markdown]
# ## Summary & Conclusion
#
# ## Summary
#
# - Study hours have a moderate positive effect on exam scores.
# - Attendance shows the strongest impact on performance.
# - Sleep hours do not show a strong relationship with exam scores.
# - Motivation has a slight effect, but not as strong as other factors.
