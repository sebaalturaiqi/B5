# %% [markdown]
# #name : seba saud

# %% [markdown]
# Question 1: Correlation vs. Causation
# The map showed a high concentration of deaths near the Broad Street pump. However, proximity alone only proves a correlation. What specific steps did Snow take to move his argument from correlation (deaths happen near the pump) to causation (the pump water is causing the deaths)?

# %% [markdown]
# To move his argument from correlation to causation, John Snow rigorously investigated the anomalies and outliers in his spatial data. While his map showed a strong correlation between cholera deaths and proximity to the Broad Street pump, he focused on cases that broke this geographic pattern to prove that specific consumption of the water—not the "bad air" in the area—was the actual cause.
#
# He investigated three key exceptions:
# **The Brewery:** A large brewery was located very close to the Broad Street pump, but none of its workers contracted cholera. Snow discovered that the workers rarely drank from the public pump because they received a daily allowance of beer and the brewery had its own private deep well.
# **The Workhouse:** A nearby workhouse was completely surrounded by cholera cases but experienced almost no deaths. Snow found that they, too, relied on their own private well instead of the Broad Street pump.
# **The Hampstead Widow:** A widow died of cholera miles away in Hampstead, an area entirely free of the outbreak. Snow visited her home and learned she used to live in Soho and had a servant fetch a large bottle of Broad Street water every week because she liked its taste. Her visiting niece also drank the water and died.
# By investigating these outliers, Snow demonstrated that the variable controlling the disease was not simply proximity to the pump or the local air, but the actual ingestion of the Broad Street water. The fact that people living nearby survived by not drinking the water, and people living far away died by drinking it, provided the strong evidence needed to move from correlation to causation.

# %% [markdown]
# Question 2: The Danger of Missing Data
# Imagine if Snow had only collected data from the local hospitals, rather than walking the streets and knocking on doors. How would this have changed his dataset, and how might it have altered his conclusions?

# %% [markdown]
# If John Snow had relied solely on hospital records instead of walking the streets and knocking on doors, his dataset would have lacked the crucial, household-level details that were essential to his discovery. Specifically, he would have missed gathering precise data on the **location of the home** and the specific **source of their drinking water**.
#
# This altered dataset would have fundamentally changed his conclusions in several ways:
#
# *   **Missing the Anomaly Cases:** Snow's argument relied heavily on investigating outliers that he found by knocking on doors. By only checking hospital records, he likely would have missed the critical case of the **Hampstead Widow**, who died miles away from the Soho outbreak but had a servant fetch Broad Street water because she liked the taste. He also would not have discovered why people living in the middle of the outbreak zone—such as the workers at the nearby **Brewery** and the residents of the **Workhouse**—survived, as he only learned about their private wells and beer allowances through direct neighborhood investigation.
# *   **Failing to Disprove the Miasma Theory:** Broad hospital data would have only shown a general spike of cholera cases coming from the Soho district. Without the exact geographic mapping of deaths forming a concentrated cluster around the **Broad Street pump**, the data would likely have appeared to support the prevailing medical consensus: the **"miasma theory,"** which blamed the deaths on the foul-smelling, poisoned air of the crowded neighborhood.
# *   **Inability to Prove Causation:** By actively interviewing families, Snow was able to gather the specific, verifiable evidence needed to prove that the disease was controlled by the **specific consumption of water from the Broad Street pump**, rather than mere proximity to bad air. Without this hands-on data collection, he would not have been able to pinpoint the actual source and prompt the local Board of Guardians to **remove the pump handle**, an intervention that ultimately stopped the outbreak.
#
# Ultimately, if Snow had only collected generalized data, he would have only seen the broader trend of an outbreak in Soho, completely missing the granular evidence required to find the pattern, explain the anomalies, and uncover the true cause of the disease.

# %% [markdown]
# Question 3: The “Miasma” of Today
# The “miasma theory” was a widely accepted consensus that was fundamentally incorrect but seemed to explain the surface-level facts (Soho smelled bad, and people in Soho were dying). What is a modern example of a “miasma”—a widely accepted assumption in business, society, or science that might fall apart if rigorously tested with data?

# %% [markdown]
# The provided sources do not contain a specific modern example of a "miasma" in business, society, or science. However, they do explain that the core purpose of **Data Science** today is to dismantle these types of unverified assumptions by "using evidence to uncover the truth of a situation and making informed decisions".
#
# To answer your question with a modern example, I must step outside the provided text *(please note that this specific example is not from your sources, and you may want to independently verify it)*.
#
# A modern business "miasma" might be the widespread assumption that **open-plan offices increase employee collaboration and productivity**. Much like the miasma theory—which seemed to make sense on the surface because Soho was crowded and smelled bad—the open-office assumption seems logical at first glance: if there are no walls, people will naturally talk more and collaborate better. However, when rigorously tested with data (such as tracking actual face-to-face interactions, daily output, and employee surveys), researchers often find the exact opposite—that open-plan offices actually decrease collaboration and increase distractions as workers wear headphones to tune out the noise.
#
# To debunk a modern assumption like this, professionals use the exact same methodology John Snow pioneered, which forms the foundation of the modern **Data Science Life Cycle**:
#
# *   **Questioning Assumptions:** Refusing to blindly accept the consensus because it lacks "rigorous empirical support".
# *   **Data Collection & Cleaning:** Gathering raw, verifiable information (like communication logs or productivity metrics) and standardizing it so that errors do not skew the final results.
# *   **Exploratory Data Analysis (EDA):** Calculating statistics and creating visual charts to find trends and correlations, much like Snow mapping the cholera deaths.
# *   **Investigating Outliers:** Looking closely at the exceptions to the pattern rather than ignoring them.
# *   **Actionable Insight:** Presenting the evidence to decision-makers to implement a targeted intervention—the modern equivalent of having the Broad Street pump handle removed.
#
# Ultimately, modern data science is designed to target today's "miasmas" by giving us the tools to "gather data, find the pattern, explain the anomalies, and remove the pump handle".
