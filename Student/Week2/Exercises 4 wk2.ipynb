# %% [markdown]
# #name:seba saud

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
result = chipo[chipo['item_price'] > 10]
print(result.head())
# Out:
#     order_id  quantity        item_name  \
# 4          2         2     Chicken Bowl
# 5          3         1     Chicken Bowl
# 7          4         1    Steak Burrito
# 13         7         1     Chicken Bowl
# 23        12         1  Chicken Burrito
#
#                                    choice_description  item_price
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23  [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
chipo['product_price'] = chipo['item_price']
result = chipo[['item_name', 'choice_description', 'product_price']]
print(result.head())
# Out:
#                                item_name  \
# 0           Chips and Fresh Tomato Salsa
# 1                                   Izze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili Salsa
# 4                           Chicken Bowl
#
#                                   choice_description  product_price
# 0                                                NaN           2.39
# 1                                       [Clementine]           3.39
# 2                                            [Apple]           3.39
# 3                                                NaN           2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...          16.98

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
sorted_items = chipo.sort_values(by='item_name')
print(sorted_items.head())
# Out:
#       order_id  quantity          item_name choice_description  item_price  \
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]       12.98
# 341        148         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 1849       749         1  6 Pack Soft Drink             [Coke]        6.49
# 1860       754         1  6 Pack Soft Drink        [Diet Coke]        6.49
# 2713      1076         1  6 Pack Soft Drink             [Coke]        6.49
#
#       product_price
# 3389          12.98
# 341            6.49
# 1849           6.49
# 1860           6.49
# 2713           6.49

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
most_expensive = chipo.sort_values(by='item_price', ascending=False)
print("expensive:")
print(most_expensive.head(1))
print("amount:", most_expensive.iloc[0]['quantity'])
# Out:
# expensive:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  product_price
# 3598       44.25          44.25
# amount: 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie = chipo[chipo['item_name'] == 'Veggie Salad Bowl']
print("Number of Veggie Salad Bowl orders:", len(veggie))
print(veggie.head())
# Out:
# Number of Veggie Salad Bowl orders: 18
#      order_id  quantity          item_name  \
# 186        83         1  Veggie Salad Bowl
# 295       128         1  Veggie Salad Bowl
# 455       195         1  Veggie Salad Bowl
# 496       207         1  Veggie Salad Bowl
# 960       394         1  Veggie Salad Bowl
#
#                                     choice_description  item_price  \
# 186  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 295  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...       11.25
# 455  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 496  [Fresh Tomato Salsa, [Rice, Lettuce, Guacamole...       11.25
# 960  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
#
#      product_price
# 186          11.25
# 295          11.25
# 455          11.25
# 496          11.25
# 960           8.75

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
soda = chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)]
print(" NO ORDERS:", len(soda))
print(soda.head())
# Out:
#  NO ORDERS: 20
#      order_id  quantity    item_name choice_description  item_price  \
# 18          9         2  Canned Soda           [Sprite]        2.18
# 51         23         2  Canned Soda     [Mountain Dew]        2.18
# 162        73         2  Canned Soda        [Diet Coke]        2.18
# 171        76         2  Canned Soda  [Diet Dr. Pepper]        2.18
# 350       150         2  Canned Soda        [Diet Coke]        2.18
#
#      product_price
# 18            2.18
# 51            2.18
# 162           2.18
# 171           2.18
# 350           2.18
