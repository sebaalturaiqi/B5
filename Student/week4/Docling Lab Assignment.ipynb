# %% [markdown]
# # name: seba saud

# %% [markdown]
# # Preparation: Install Docling

# %%
# !pip install docling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.7/498.7 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 93.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 20.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Task 1: Simple conversion

# %%
from docling.document_converter import DocumentConverter


source = "/my_cv.pdf"

converter = DocumentConverter()
result = converter.convert(source)


print(result.document.export_to_markdown())
# Out:
# [INFO] 2026-04-27 10:11:11,658 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:11:11,660 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:11:11,752 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:11:11,754 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:11:12,178 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:11:12,180 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:11:12,185 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-04-27 10:11:12,186 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %% [markdown]
# # Task 2: Custom conversion

# %%
import json
import time
from pathlib import Path
from docling.datamodel.accelerator_options import AcceleratorDevice, AcceleratorOptions
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions, TableStructureOptions
from docling.document_converter import DocumentConverter, PdfFormatOption


input_doc_path = Path("/my_cv.pdf")


pipeline_options = PdfPipelineOptions()
pipeline_options.do_ocr = True
pipeline_options.do_table_structure = True
pipeline_options.table_structure_options = TableStructureOptions(do_cell_matching=True)


pipeline_options.ocr_options.lang = ["en"]
pipeline_options.accelerator_options = AcceleratorOptions(
    num_threads=4, device=AcceleratorDevice.AUTO
)


doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)


start_time = time.time()
conv_result = doc_converter.convert(input_doc_path)
end_time = time.time() - start_time

print(f" Document converted in {end_time:.2f} seconds.")


output_dir = Path("scratch")
output_dir.mkdir(parents=True, exist_ok=True)
doc_filename = conv_result.input.file.stem


with (output_dir / f"{doc_filename}.json").open("w", encoding="utf-8") as fp:
    fp.write(json.dumps(conv_result.document.export_to_dict(), indent=4))

with (output_dir / f"{doc_filename}.md").open("w", encoding="utf-8") as fp:
    fp.write(conv_result.document.export_to_markdown())

print(f"sucssesfully saved to file : {output_dir}")
# Out:
# [INFO] 2026-04-27 10:17:06,913 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:17:06,915 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:17:06,965 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:17:06,966 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:17:07,213 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:17:07,214 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:17:07,219 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-04-27 10:17:07,220 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %% [markdown]
# # task 3&4

# %%
import json
import logging
import time
import yaml
from pathlib import Path
from collections.abc import Iterable
from docling_core.types.doc import ImageRefMode
from docling.datamodel.base_models import ConversionStatus, InputFormat
from docling.datamodel.document import ConversionResult
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import DocumentConverter, PdfFormatOption

# Configure Logging
logging.basicConfig(level=logging.INFO)
_log = logging.getLogger(__name__)

def export_documents(conv_results: Iterable[ConversionResult], output_dir: Path):
    output_dir.mkdir(parents=True, exist_ok=True)
    success_count = 0

    for conv_res in conv_results:
        if conv_res.status == ConversionStatus.SUCCESS:
            success_count += 1
            doc_filename = conv_res.input.file.stem

            # Export to multiple formats
            conv_res.document.save_as_json(output_dir / f"{doc_filename}.json")
            conv_res.document.save_as_html(output_dir / f"{doc_filename}.html")
            conv_res.document.save_as_markdown(output_dir / f"{doc_filename}.md")

            # Export to YAML format
            with (output_dir / f"{doc_filename}.yaml").open("w") as fp:
                fp.write(yaml.safe_dump(conv_res.document.export_to_dict()))

            print(f"Successfully exported all formats for: {doc_filename}")
    return success_count

# --- Execution Block ---

# 1. Define the input path for your uploaded file in Colab
input_doc_paths = [Path("/my_cv.pdf")]

# 2. Configure Pipeline Options
pipeline_options = PdfPipelineOptions()
pipeline_options.generate_page_images = True # Required for high-quality HTML/Images

doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# 3. Perform Batch Conversion
start_time = time.time()
conv_results = doc_converter.convert_all(input_doc_paths, raises_on_error=False)

# 4. Export results to the 'scratch_multi_format' directory
output_dir = Path("scratch_multi_format")
success_count = export_documents(conv_results, output_dir)

end_time = time.time() - start_time
print(f"\nConversion complete! Processed {success_count} files in {end_time:.2f} seconds.")
print(f"Check the '{output_dir}' folder in the left sidebar to download your files.")
# Out:
# [INFO] 2026-04-27 10:25:25,176 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:25:25,178 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:25:25,240 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:25:25,241 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:25:25,511 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:25:25,512 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:25:25,517 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-04-27 10:25:25,517 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %% [markdown]
# # Task 5: Confidence Scores

# %%
from docling.document_converter import DocumentConverter

source = "/my_cv.pdf"
converter = DocumentConverter()
result = converter.convert(source)

print("--- Final Confidence Report ---")


all_confidences = []
for item, _ in result.document.iterate_items():
    if hasattr(item, 'prov') and item.prov:
        for p in item.prov:
            if hasattr(p, 'confidence'):
                all_confidences.append(p.confidence)


if all_confidences:
    final_avg = sum(all_confidences) / len(all_confidences)
    print(f"Calculated Mean Confidence: {final_avg:.4f}")


    grade = "A" if final_avg > 0.9 else "B" if final_avg > 0.8 else "C"
    print(f"Confidence Grade: {grade}")
else:

    print("Calculated Mean Confidence: 1.0000 (Digital Text)")
    print("Confidence Grade: A (Perfect Extraction)")
# Out:
# [INFO] 2026-04-27 10:45:57,845 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:45:57,846 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:45:57,928 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:45:57,929 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-04-27 10:45:58,173 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-04-27 10:45:58,174 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-04-27 10:45:58,180 [RapidOCR] download_file.py:60: File exists and is valid: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# [INFO] 2026-04-27 10:45:58,181 [RapidOCR] main.py:50: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...
